# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ## Data Load

# %%
import pandas as pd
import numpy as np

# %%
file_in = "df_processed.csv"
file_out = "df_processed_sentimentValue.csv"

# %%
df = pd.read_csv(file_in)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                       _id  Unnamed: 2  Id  \
# 0             0           0  660136d21ab34c5dcc314932           3   4
# 1             1           1  660136d21ab34c5dcc314934           6   7
# 2             2           2  660136d21ab34c5dcc314935           7   8
# 3             3           3  660136d21ab34c5dcc314938           9  10
# 4             4           4  660136d21ab34c5dcc31493d          13  14
#
#     ProductId          UserId         ProfileName  HelpfulnessNumerator  \
# 0  B000UA0QIQ  A395BORC6FGVXV                Karl                     3
# 1  B006K2ZZ7K  A1SP2KVKFXXRU1   David C. Sullivan                     0
# 2  B006K2ZZ7K  A3JRGQVEQN31IQ  Pamela G. Williams                     0
# 3  B00171APVA  A21BT40VZCCYT4       Carol A. Reed                     0
# 4  B001GVISJM  A18ECVX2RJ7HUE     willie "roadie"                     2
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       3      2  2011-06-13
# ...

# %% [markdown]
# ## Process

# %%
# > code goes here

# %% [markdown]
# ## Data save

# %%
# ESTA CELDA ES TEMPORAL, PARA GENERAL UNA COLUMNS CON VALORES ALEATORIOS
df['sentiment-value'] = np.random.uniform(-1, 1, df.shape[0])
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                       _id  Unnamed: 2  Id  \
# 0             0           0  660136d21ab34c5dcc314932           3   4
# 1             1           1  660136d21ab34c5dcc314934           6   7
# 2             2           2  660136d21ab34c5dcc314935           7   8
# 3             3           3  660136d21ab34c5dcc314938           9  10
# 4             4           4  660136d21ab34c5dcc31493d          13  14
#
#     ProductId          UserId         ProfileName  HelpfulnessNumerator  \
# 0  B000UA0QIQ  A395BORC6FGVXV                Karl                     3
# 1  B006K2ZZ7K  A1SP2KVKFXXRU1   David C. Sullivan                     0
# 2  B006K2ZZ7K  A3JRGQVEQN31IQ  Pamela G. Williams                     0
# 3  B00171APVA  A21BT40VZCCYT4       Carol A. Reed                     0
# 4  B001GVISJM  A18ECVX2RJ7HUE     willie "roadie"                     2
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       3      2  2011-06-13
# ...

# %%
df.to_csv(file_out)
