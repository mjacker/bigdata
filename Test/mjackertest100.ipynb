# %%
# Database
import pymongo

# Preprocessing
import os
import pandas as pd
import numpy as np

# from datetime import datetime
# from natsort import natsort_keygen
# import re
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer

# Data Visualization
# import matplotlib.pyplot as plt
# import plotly.express as px

# %% [markdown]
# ### Login

# %%
f=open("./../.my-mongo-credential-test","r")
lines=f.readlines()
username=lines[0].strip()
password=lines[1].strip()
f.close()

# %%
# remote
client = pymongo.MongoClient(f'mongodb+srv://{username}:{password}@cluster0.ibac3d0.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')

# %%
# localhost
# client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
client
# Out:
# MongoClient(host=['ac-slpho2y-shard-00-00.ibac3d0.mongodb.net:27017', 'ac-slpho2y-shard-00-02.ibac3d0.mongodb.net:27017', 'ac-slpho2y-shard-00-01.ibac3d0.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-11ongf-shard-0', tls=True)

# %%
client.server_info()
# Out:
# {'version': '7.0.8',
#  'gitVersion': 'c5d33e55ba38d98e2f48765ec4e55338d67a4a64',
#  'modules': ['enterprise'],
#  'allocator': 'tcmalloc',
#  'javascriptEngine': 'mozjs',
#  'sysInfo': 'deprecated',
#  'versionArray': [7, 0, 8, 0],
#  'bits': 64,
#  'debug': False,
#  'maxBsonObjectSize': 16777216,
#  'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'],
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1712562427, 12),
#   'signature': {'hash': b'\xbfKX\x85\x05\x9e\xc9%\xbf\x93j\xb5\x01\xea\x16\xd3~G\x89\xe6',
#    'keyId': 7299119760740974594}},
#  'operationTime': Timestamp(1712562427, 12)}

# %% [markdown]
# ## Show all collection names

# %%
 print(client.list_database_names())
# Out:
# ['sample_guides', 'test10', 'admin', 'local']

# %% [markdown]
# ## Examplt to upload 10 rows element to mongodb atlas

# %%
db=client['test10']
collection = db['test10']

# %%
mylist = [
  { "_id": 1, "name": "John", "address": "Highway 37"},
  { "_id": 2, "name": "Peter", "address": "Lowstreet 27"},
  { "_id": 3, "name": "Amy", "address": "Apple st 652"},
  { "_id": 4, "name": "Hannah", "address": "Mountain 21"},
  { "_id": 5, "name": "Michael", "address": "Valley 345"},
  { "_id": 6, "name": "Sandy", "address": "Ocean blvd 2"},
  { "_id": 7, "name": "Betty", "address": "Green Grass 1"},
  { "_id": 8, "name": "Richard", "address": "Sky st 331"},
  { "_id": 9, "name": "Susan", "address": "One way 98"},
  { "_id": 10, "name": "Vicky", "address": "Yellow Garden 2"},
]

# x = collection.insert_many(mylist)

# %% [markdown]
# ## Upload 100 rows test data to mongodbAtlas

# %%
db=client['test100']
collection = db['test100']

# %%
data = pd.read_csv("./amazon_100.csv")
payload = json.loads(data.to_json(orient='records'))
# collection.remove()
collection.insert_many(payload)
# Out:
# InsertManyResult([ObjectId('6613a11e7615b939badf0570'), ObjectId('6613a11e7615b939badf0571'), ObjectId('6613a11e7615b939badf0572'), ObjectId('6613a11e7615b939badf0573'), ObjectId('6613a11e7615b939badf0574'), ObjectId('6613a11e7615b939badf0575'), ObjectId('6613a11e7615b939badf0576'), ObjectId('6613a11e7615b939badf0577'), ObjectId('6613a11e7615b939badf0578'), ObjectId('6613a11e7615b939badf0579'), ObjectId('6613a11e7615b939badf057a'), ObjectId('6613a11e7615b939badf057b'), ObjectId('6613a11e7615b939badf057c'), ObjectId('6613a11e7615b939badf057d'), ObjectId('6613a11e7615b939badf057e'), ObjectId('6613a11e7615b939badf057f'), ObjectId('6613a11e7615b939badf0580'), ObjectId('6613a11e7615b939badf0581'), ObjectId('6613a11e7615b939badf0582'), ObjectId('6613a11e7615b939badf0583'), ObjectId('6613a11e7615b939badf0584'), ObjectId('6613a11e7615b939badf0585'), ObjectId('6613a11e7615b939badf0586'), ObjectId('6613a11e7615b939badf0587'), ObjectId('6613a11e7615b939badf0588'), ObjectId('6613a11e7615b939badf0589'), ObjectId('6613a11e7615b939badf058a'), ObjectId('6613a11e7615b939badf058b'), ObjectId('6613a11e7615b939badf058c'), ObjectId('6613a11e7615b939badf058d'), ObjectId('6613a11e7615b939badf058e'), ObjectId('6613a11e7615b939badf058f'), ObjectId('6613a11e7615b939badf0590'), ObjectId('6613a11e7615b939badf0591'), ObjectId('6613a11e7615b939badf0592'), ObjectId('6613a11e7615b939badf0593'), ObjectId('6613a11e7615b939badf0594'), ObjectId('6613a11e7615b939badf0595'), ObjectId('6613a11e7615b939badf0596'), ObjectId('6613a11e7615b939badf0597'), ObjectId('6613a11e7615b939badf0598'), ObjectId('6613a11e7615b939badf0599'), ObjectId('6613a11e7615b939badf059a'), ObjectId('6613a11e7615b939badf059b'), ObjectId('6613a11e7615b939badf059c'), ObjectId('6613a11e7615b939badf059d'), ObjectId('6613a11e7615b939badf059e'), ObjectId('6613a11e7615b939badf059f'), ObjectId('6613a11e7615b939badf05a0'), ObjectId('6613a11e7615b939badf05a1'), ObjectId('6613a11e7615b939badf05a2'), ObjectId('6613a11e7615b939badf05a3'), ObjectId('6613a11e7615b939badf05a4'), ObjectId('6613a11e7615b939badf05a5'), ObjectId('6613a11e7615b939badf05a6'), ObjectId('6613a11e7615b939badf05a7'), ObjectId('6613a11e7615b939badf05a8'), ObjectId('6613a11e7615b939badf05a9'), ObjectId('6613a11e7615b939badf05aa'), ObjectId('6613a11e7615b939badf05ab'), ObjectId('6613a11e7615b939badf05ac'), ObjectId('6613a11e7615b939badf05ad'), ObjectId('6613a11e7615b939badf05ae'), ObjectId('6613a11e7615b939badf05af'), ObjectId('6613a11e7615b939badf05b0'), ObjectId('6613a11e7615b939badf05b1'), ObjectId('6613a11e7615b939badf05b2'), ObjectId('6613a11e7615b939badf05b3'), ObjectId('6613a11e7615b939badf05b4'), ObjectId('6613a11e7615b939badf05b5'), ObjectId('6613a11e7615b939badf05b6'), ObjectId('6613a11e7615b939badf05b7'), ObjectId('6613a11e7615b939badf05b8'), ObjectId('6613a11e7615b939badf05b9'), ObjectId('6613a11e7615b939badf05ba'), ObjectId('6613a11e7615b939badf05bb'), ObjectId('6613a11e7615b939badf05bc'), ObjectId('6613a11e7615b939badf05bd'), ObjectId('6613a11e7615b939badf05be'), ObjectId('6613a11e7615b939badf05bf'), ObjectId('6613a11e7615b939badf05c0'), ObjectId('6613a11e7615b939badf05c1'), ObjectId('6613a11e7615b939badf05c2'), ObjectId('6613a11e7615b939badf05c3'), ObjectId('6613a11e7615b939badf05c4'), ObjectId('6613a11e7615b939badf05c5'), ObjectId('6613a11e7615b939badf05c6'), ObjectId('6613a11e7615b939badf05c7'), ObjectId('6613a11e7615b939badf05c8'), ObjectId('6613a11e7615b939badf05c9'), ObjectId('6613a11e7615b939badf05ca'), ObjectId('6613a11e7615b939badf05cb'), ObjectId('6613a11e7615b939badf05cc'), ObjectId('6613a11e7615b939badf05cd'), ObjectId('6613a11e7615b939badf05ce'), ObjectId('6613a11e7615b939badf05cf'), ObjectId('6613a11e7615b939badf05d0'), ObjectId('6613a11e7615b939badf05d1'), ObjectId('6613a11e7615b939badf05d2'), ObjectId('6613a11e7615b939badf05d3')], acknowledged=True)

# %%
payload
# Out:
# [{'Unnamed: 0': 0,
#   'Id': 4,
#   'ProductId': 'B000UA0QIQ',
#   'UserId': 'A395BORC6FGVXV',
#   'ProfileName': 'Karl',
#   'HelpfulnessNumerator': 3,
#   'HelpfulnessDenominator': 3,
#   'Score': 2,
#   'Time': 1307923200,
#   'Summary': 'Cough Medicine',
#   'Text': 'If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The flavor is very medicinal.',
#   'ProductURL': 'https://www.amazon.com/dp/B000UA0QIQ'},
#  {'Unnamed: 0': 1,
#   'Id': 7,
#   'ProductId': 'B006K2ZZ7K',
#   'UserId': 'A1SP2KVKFXXRU1',
#   'ProfileName': 'David C. Sullivan',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1340150400,
#   'Summary': 'Great!  Just as good as the expensive brands!',
#   'Text': "This saltwater taffy had great flavors and was very soft and chewy.  Each candy was individually wrapped well.  None of the candies were stuck together, which did happen in the expensive version, Fralinger's.  Would highly recommend this candy!  I served it at a beach-themed party and everyone loved it!",
#   'ProductURL': 'https://www.amazon.com/dp/B006K2ZZ7K'},
#  {'Unnamed: 0': 2,
#   'Id': 8,
#   'ProductId': 'B006K2ZZ7K',
#   'UserId': 'A3JRGQVEQN31IQ',
#   'ProfileName': 'Pamela G. Williams',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1336003200,
#   'Summary': 'Wonderful, tasty taffy',
#   'Text': 'This taffy is so good.  It is very soft and chewy.  The flavors are amazing.  I would definitely recommend you buying it.  Very satisfying!!',
#   'ProductURL': 'https://www.amazon.com/dp/B006K2ZZ7K'},
#  {'Unnamed: 0': 3,
#   'Id': 10,
#   'ProductId': 'B00171APVA',
#   'UserId': 'A21BT40VZCCYT4',
#   'ProfileName': 'Carol A. Reed',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1351209600,
#   'Summary': 'Healthy Dog Food',
#   'Text': 'This is a very healthy dog food. Good for their digestion. Also good for small puppies. My dog eats her required amount at every feeding.',
#   'ProductURL': 'https://www.amazon.com/dp/B00171APVA'},
#  {'Unnamed: 0': 4,
#   'Id': 14,
#   'ProductId': 'B001GVISJM',
#   'UserId': 'A18ECVX2RJ7HUE',
#   'ProfileName': 'willie "roadie"',
#   'HelpfulnessNumerator': 2,
#   'HelpfulnessDenominator': 2,
#   'Score': 4,
#   'Time': 1288915200,
#   'Summary': 'fresh and greasy!',
#   'Text': 'good flavor! these came securely packed... they were fresh and delicious! i love these Twizzlers!',
#   'ProductURL': 'https://www.amazon.com/dp/B001GVISJM'},
#  {'Unnamed: 0': 5,
#   'Id': 17,
#   'ProductId': 'B001GVISJM',
#   'UserId': 'A3KLWF6WQ5BNYO',
#   'ProfileName': 'Erica Neathery',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 2,
#   'Time': 1348099200,
#   'Summary': 'poor taste',
#   'Text': 'I love eating them and they are good for watching TV and looking at movies! It is not too sweet. I like to transfer them to a zip lock baggie so they stay fresh so I can take my time eating them.',
#   'ProductURL': 'https://www.amazon.com/dp/B001GVISJM'},
#  {'Unnamed: 0': 6,
#   'Id': 18,
#   'ProductId': 'B001GVISJM',
#   'UserId': 'AFKW14U97Z6QO',
#   'ProfileName': 'Becca',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1345075200,
#   'Summary': 'Love it!',
#   'Text': 'I am very satisfied with my Twizzler purchase.  I shared these with others and we have all enjoyed them.  I will definitely be ordering more.',
#   'ProductURL': 'https://www.amazon.com/dp/B001GVISJM'},
#  {'Unnamed: 0': 7,
#   'Id': 25,
#   'ProductId': 'B001GVISJM',
#   'UserId': 'A22P2J09NJ9HKE',
#   'ProfileName': 'S. Cabanaugh "jilly pepper"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1295481600,
#   'Summary': 'Please sell these in Mexico!!',
#   'Text': "I have lived out of the US for over 7 yrs now, and I so miss my Twizzlers!!  When I go back to visit or someone visits me, I always stock up.  All I can say is YUM!<br />Sell these in Mexico and you will have a faithful buyer, more often than I'm able to buy them right now.",
#   'ProductURL': 'https://www.amazon.com/dp/B001GVISJM'},
#  {'Unnamed: 0': 8,
#   'Id': 26,
#   'ProductId': 'B001GVISJM',
#   'UserId': 'A3FONPR03H3PJS',
#   'ProfileName': 'Deborah S. Linzer "Cat Lady"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1288310400,
#   'Summary': 'Twizzlers - Strawberry',
#   'Text': 'Product received is as advertised.<br /><br /><a href="http://www.amazon.com/gp/product/B001GVISJM">Twizzlers, Strawberry, 16-Ounce Bags (Pack of 6)</a>',
#   'ProductURL': 'https://www.amazon.com/dp/B001GVISJM'},
#  {'Unnamed: 0': 9,
#   'Id': 31,
#   'ProductId': 'B003F6UO7K',
#   'UserId': 'AFM0O9480F04W',
#   'ProfileName': 'Sherril',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1297641600,
#   'Summary': 'Great machine!',
#   'Text': "I have never been a huge coffee fan. However, my mother purchased this little machine and talked me into trying the Latte Macciato. No Coffee Shop has a better one and I like most of the other products, too (as a usually non-coffee drinker!).<br />The little Dolche Guesto Machine is super easy to use and prepares a really good Coffee/Latte/Cappuccino/etc in less than a minute (if water is heated up). I would recommend the Dolce Gusto to anyone. Too good for the price and I'am getting one myself! :)",
#   'ProductURL': 'https://www.amazon.com/dp/B003F6UO7K'},
#  {'Unnamed: 0': 10,
#   'Id': 35,
#   'ProductId': 'B001EO5QW8',
#   'UserId': 'A2EB6OGOWCRU5H',
#   'ProfileName': 'CorbyJames',
#   'HelpfulnessNumerator': 9,
#   'HelpfulnessDenominator': 9,
#   'Score': 5,
#   'Time': 1175212800,
#   'Summary': 'Great Irish oatmeal for those in a hurry!',
#   'Text': "Instant oatmeal can become soggy the minute the water hits the bowl. McCann's Instant Oatmeal holds its texture, has excellent flavor, and is good for you all at the same time. McCann's regular oat meal is excellent, too, but may take a bit longer to prepare than most have time for in the morning. This is the best instant brand I've ever eaten, and a very close second to the non-instant variety.<br /><br />McCann's Instant Irish Oatmeal, Variety Pack of Regular, Apples & Cinnamon, and Maple & Brown Sugar, 10-Count Boxes (Pack of 6)",
#   'ProductURL': 'https://www.amazon.com/dp/B001EO5QW8'},
#  {'Unnamed: 0': 11,
#   'Id': 37,
#   'ProductId': 'B001EO5QW8',
#   'UserId': 'A1MYS9LFFBIYKM',
#   'ProfileName': 'Abby Chase "gluten free"',
#   'HelpfulnessNumerator': 2,
#   'HelpfulnessDenominator': 2,
#   'Score': 5,
#   'Time': 1190851200,
#   'Summary': 'Love Gluten Free Oatmeal!!!',
#   'Text': "For those of us with celiac disease this product is a lifesaver and what could be better than getting it at almost half the price of the grocery or health food store!  I love McCann's instant oatmeal - all flavors!!!<br /><br />Thanks,<br />Abby",
#   'ProductURL': 'https://www.amazon.com/dp/B001EO5QW8'},
#  {'Unnamed: 0': 12,
#   'Id': 40,
#   'ProductId': 'B001EO5QW8',
#   'UserId': 'AO80AC8313NIZ',
#   'ProfileName': 'kYpondman',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1317168000,
#   'Summary': "Wife's favorite Breakfast",
#   'Text': 'I ordered this for my wife as it was reccomended by our daughter.  She has this almost every morning and likes all flavors.  She\'s happy, I\'m happy!!!<br /><a href="http://www.amazon.com/gp/product/B001EO5QW8">McCANN\'S Instant Irish Oatmeal, Variety Pack of Regular, Apples & Cinnamon, and Maple & Brown Sugar, 10-Count Boxes (Pack of 6)</a>',
#   'ProductURL': 'https://www.amazon.com/dp/B001EO5QW8'},
#  {'Unnamed: 0': 13,
#   'Id': 39,
#   'ProductId': 'B001EO5QW8',
#   'UserId': 'A2GHZ2UTV2B0CD',
#   'ProfileName': 'JERRY REITH',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 4,
#   'Time': 1350777600,
#   'Summary': 'GOOD WAY TO START THE DAY....',
#   'Text': 'I WAS VISITING MY FRIEND NATE THE OTHER MORNING FOR COFFEE , HE CAME OUT OF HIS STORAGE ROOM WITH ( A PACKET OF McCANNS INSTANT IRISH OATMEAL .) HE SUGGESTED THAT I TRY IT FOR MY OWN USE ,IN MY STASH . SOMETIMES NATE DOSE NOT GIVE YOU A CHANCE TO SAY NO , SO I ENDED UP TRYING THE APPLE AND CINN . FOUND IT TO BE VERY TASTEFULL WHEN MADE WITH WATER OR POWDERED MILK . IT GOES GOOD WITH O.J. AND COFFEE AND A SLICE OF TOAST AND YOUR READY TO TAKE ON THE WORLD...OR THE DAY AT LEAST..  JERRY REITH...',
#   'ProductURL': 'https://www.amazon.com/dp/B001EO5QW8'},
#  {'Unnamed: 0': 14,
#   'Id': 42,
#   'ProductId': 'B001EO5QW8',
#   'UserId': 'A1WK4ALVZDYPUE',
#   'ProfileName': 'Dick Baldwin "christobe"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1302134400,
#   'Summary': 'Oatmeal For Oatmeal Lovers',
#   'Text': "McCann's makes oatmeal for every oatmeal connoisseur, whether one likes it from the raw pellet state that cooks for half an hour, to the sloth addled instant, which can be done in the microwave for under three minutes. It's all good, that's for sure, and the beauty of the instant variety is that it is available in different flavors as well as regular.<br />  This variety pack allows different tastes to be explored, as well as giving you a chance to experience the difference between McCann's and other well-known oatmeals. What I personally like about McCann's is that it cooks up thicker and with more body than the top brand here in America. The Apples & Cinnamon, though, tends to be a little liquidy so you may want to experiment with the amount of water you add. In my 1300watt microwave the oatmeal cooks up in about one minute and twenty-seven seconds, so you should also watch that to get a handle on how much time and water to use.<br />  The only bad thing -- if you can consider it a bad thing -- about this offering is that you have to buy in lot so you'll end up with six ten-count boxes. This is good if you have a whole family of oatmeal-eaters, but if you're a single person alone -- well, love oatmeal.",
#   'ProductURL': 'https://www.amazon.com/dp/B001EO5QW8'},
#  {'Unnamed: 0': 15,
#   'Id': 47,
#   'ProductId': 'B001EO5QW8',
#   'UserId': 'AQLL2R1PPR46X',
#   'ProfileName': 'grumpyrainbow',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1192752000,
#   'Summary': 'good',
#   'Text': "Good oatmeal.  I like the apple cinnamon the best.  Though I wouldn't follow the directions on the package since it always comes out too soupy for my taste.  That could just be me since I like my oatmeal really thick to add some milk on top of.",
#   'ProductURL': 'https://www.amazon.com/dp/B001EO5QW8'},
#  {'Unnamed: 0': 16,
#   'Id': 48,
#   'ProductId': 'B001EO5QW8',
#   'UserId': 'A26AY1TFK8BQXQ',
#   'ProfileName': 'kbogo "shoelover"',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 2,
#   'Score': 3,
#   'Time': 1200096000,
#   'Summary': 'Mushy',
#   'Text': 'The flavors are good.  However, I do not see any differce between this and Oaker Oats brand - they are both mushy.',
#   'ProductURL': 'https://www.amazon.com/dp/B001EO5QW8'},
#  {'Unnamed: 0': 17,
#   'Id': 65,
#   'ProductId': 'B005DUM9UQ',
#   'UserId': 'A2XIHNXODNZGV4',
#   'ProfileName': 'ChemProf "chem professor"',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1333584000,
#   'Summary': 'great source of electrolytes',
#   'Text': 'This product serves me well as a source of electrolytes during and after a long run or bike ride.<br />I have tried all of the flavors but really do like the grapefruit flavor... no after-taste and I actually like the slight carbonation.<br />I use other Hammer products and really like their whole product line.',
#   'ProductURL': 'https://www.amazon.com/dp/B005DUM9UQ'},
#  {'Unnamed: 0': 18,
#   'Id': 67,
#   'ProductId': 'B005DUM9UQ',
#   'UserId': 'AEFIZIJ1FK1BK',
#   'ProfileName': 'Doug',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1345161600,
#   'Summary': 'Low Carb Alternative to Gatorade',
#   'Text': 'For those of us on a low carb diet these little tablets are just the thing.<br /><br />Two years ago I started cycling again after many years but was having heart arrhythmia after longer rides in high heat.  I was drinking plain water but did a little research and thought electrolytes might be the issue.  Gatorade wasn\'t an option because it is so loaded with carbohydrates so I looked around for a low-carb alternative.  The "zero carb" sports drinks didn\'t help so what to do?  One day I ran across these at my bike shop so tried a tube of them.....voila!...problem solved!!<br /><br />I\'ve shared them with two friends in particular whose problems with leg cramps were resolved while using these.<br /><br />These guys got it right -- they are superbly formulated and simply work.....',
#   'ProductURL': 'https://www.amazon.com/dp/B005DUM9UQ'},
#  {'Unnamed: 0': 19,
#   'Id': 68,
#   'ProductId': 'B005DUM9UQ',
#   'UserId': 'A8OFFIAL6XTOH',
#   'ProfileName': 'Bill Shirer',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 1,
#   'Score': 2,
#   'Time': 1338422400,
#   'Summary': 'Taste is not so good.',
#   'Text': "I purchased the Mango flavor, and to me it doesn't take like Mango at all.  There is no hint of sweetness, and unfortunately there is a hint or aftertaste almost like licorice.  I've been consuming various sports nutrition products for decades, so I'm familiar and have come to like the taste of the most of the products I've tried.  The mango flavor is one of the least appealing I've tasted.  It's not terrible, but it's bad enough that I notice the bad taste every sip I take.",
#   'ProductURL': 'https://www.amazon.com/dp/B005DUM9UQ'},
#  {'Unnamed: 0': 20,
#   'Id': 58,
#   'ProductId': 'B004N5KULM',
#   'UserId': 'ASCNNAJU6SXF8',
#   'ProfileName': 'S. Beck',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1336176000,
#   'Summary': 'How can you go wrong!',
#   'Text': 'It is chocolate, what can I say.  Great variety of everything our family loves.  With a family of six it goes fast here.  Perfect variety.  Kit Kat, Reeses, take five and more.',
#   'ProductURL': 'https://www.amazon.com/dp/B004N5KULM'},
#  {'Unnamed: 0': 21,
#   'Id': 59,
#   'ProductId': 'B004N5KULM',
#   'UserId': 'A2A7KXM9B4XW90',
#   'ProfileName': 'P. Kelso "Amazon all the way!"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1320364800,
#   'Summary': 'Awsome - Kids in neighborhood loved us!',
#   'Text': 'Great product, nice combination of chocolates and perfect size!  The bags had plenty, and they were shipped promptly.  The kids in the neighborhood liked our candies!',
#   'ProductURL': 'https://www.amazon.com/dp/B004N5KULM'},
#  {'Unnamed: 0': 22,
#   'Id': 76,
#   'ProductId': 'B001EPPI84',
#   'UserId': 'A27TZ4WBU7N0YF',
#   'ProfileName': 'I. So',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 1,
#   'Time': 1275004800,
#   'Summary': 'No Tea Flavor',
#   'Text': 'No tea flavor at all. Just whole brunch of artifial flavors. It is not returnable. I wasted 20+ bucks.',
#   'ProductURL': 'https://www.amazon.com/dp/B001EPPI84'},
#  {'Unnamed: 0': 23,
#   'Id': 84,
#   'ProductId': 'B0019CW0HE',
#   'UserId': 'A1FD9E5C06UB6B',
#   'ProfileName': 'BRENDA DEMERS',
#   'HelpfulnessNumerator': 5,
#   'HelpfulnessDenominator': 5,
#   'Score': 3,
#   'Time': 1301011200,
#   'Summary': 'Natural Balance Lamb and Rice',
#   'Text': 'While my dogs like all of the flavors that we have tried of this dog food, for some reason their itching increased when I tried the lamb and rice. I have some very itchy dogs and am giving them a limited ingredient dog food to try to help. The duck and sweet potato cut down on the itching significantly, but when we tried lamb and rice they started itching more once again. I like Natural Balance for the quality ingredients.',
#   'ProductURL': 'https://www.amazon.com/dp/B0019CW0HE'},
#  {'Unnamed: 0': 24,
#   'Id': 85,
#   'ProductId': 'B0019CW0HE',
#   'UserId': 'AK2CXHH9VRZ2A',
#   'ProfileName': 'I. GLENN',
#   'HelpfulnessNumerator': 4,
#   'HelpfulnessDenominator': 4,
#   'Score': 3,
#   'Time': 1313193600,
#   'Summary': 'INCREASED MY DOGS ITCHING',
#   'Text': 'Awesome dog food. However, when given to my "Boston", who has severe reactions to some food ingredients; his itching increased to violent jumping out of bed at night, scratching. As soon as I changed to a different formula, the scratching stopped. So glad Natural Balance has other choices. I guess you have to try each, until you find what\'s best for your pet.',
#   'ProductURL': 'https://www.amazon.com/dp/B0019CW0HE'},
#  {'Unnamed: 0': 25,
#   'Id': 87,
#   'ProductId': 'B0019CW0HE',
#   'UserId': 'A37N9XZBB8JYOF',
#   'ProfileName': 'Ash52',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1333670400,
#   'Summary': 'Great for my dogs allergies',
#   'Text': "My dog has a ton of allergies both environmental and food. She was on a prescription dog food before we had her tested to see what allergies she has. After we got the test back, we learned she was allergic to something in the prescription brand. So I finally found this dog food and she has done so well on this! She still has her environmental triggers, but I am happy she can finally eat something I know won't cause her pain.",
#   'ProductURL': 'https://www.amazon.com/dp/B0019CW0HE'},
#  {'Unnamed: 0': 26,
#   'Id': 96,
#   'ProductId': 'B0019CW0HE',
#   'UserId': 'A1BFNM27629VAV',
#   'ProfileName': 'E. Triebe',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1320105600,
#   'Summary': 'Good healthy dog food',
#   'Text': "I've been very pleased with the Natural Balance dog food. Our dogs have had issues with other dog foods in the past and I had someone recommend Natural Balance grain free since it is possible they were allergic to grains. Since switching I haven't had any issues. It is also helpful that have have different kibble size for larger/smaller sized dogs.",
#   'ProductURL': 'https://www.amazon.com/dp/B0019CW0HE'},
#  {'Unnamed: 0': 27,
#   'Id': 98,
#   'ProductId': 'B0019CW0HE',
#   'UserId': 'A3UII2114114PI',
#   'ProfileName': 'FuNky Faja "SiLkk"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1297296000,
#   'Summary': 'Great allergy sensitive dog food, dogs love it',
#   'Text': "Our pup has experienced allergies in forms of hotspots and itching from other dog foods. The cheap 'you can buy it anywhere' food not only have crazy preservatives in them but can cause health problems for your pets.  This food works wonders on reducing allergies and our dog loves the food.<br />This message is RAMSEY FrAnkenSteiN approved.",
#   'ProductURL': 'https://www.amazon.com/dp/B0019CW0HE'},
#  {'Unnamed: 0': 28,
#   'Id': 99,
#   'ProductId': 'B0019CW0HE',
#   'UserId': 'ABZ9F0D94YK45',
#   'ProfileName': 'Amazon-tron 3000',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1295308800,
#   'Summary': 'Perfect for our English Bulldog with Allergies',
#   'Text': "My English Bulldog had skin allergies the summer we got him at age 3.  The vet recommended we wean him off the food his previous owner gave him (Iams Lamb and Rice) and onto a new kind.  This was the second one we tried, and it has been working ever since.  It's for dogs that need a limited diet who can be sensitive to additives and proteins commonly found in commercial dog food (like chicken or beef).",
#   'ProductURL': 'https://www.amazon.com/dp/B0019CW0HE'},
#  {'Unnamed: 0': 29,
#   'Id': 101,
#   'ProductId': 'B004K2IHUO',
#   'UserId': 'A1SYSKR79LA2CB',
#   'ProfileName': 'Mycroft "Virture is its own punishment"',
#   'HelpfulnessNumerator': 4,
#   'HelpfulnessDenominator': 5,
#   'Score': 5,
#   'Time': 1233014400,
#   'Summary': 'Taste wise it is a 6 star item',
#   'Text': 'The mouth says, "How do I love thee, let me count the ways..."<br />If you like apple products a must have item.  The only draw back, shipping cost.  These are very heavy.',
#   'ProductURL': 'https://www.amazon.com/dp/B004K2IHUO'},
#  {'Unnamed: 0': 30,
#   'Id': 111,
#   'ProductId': 'B000J0HIT2',
#   'UserId': 'A1VKJN5Y1C7S5Y',
#   'ProfileName': 'Wilhelmina Robinson "Wilhelmina Robinson &#34...',
#   'HelpfulnessNumerator': 2,
#   'HelpfulnessDenominator': 2,
#   'Score': 2,
#   'Time': 1250812800,
#   'Summary': 'Low Carb Angel Food Puffs',
#   'Text': 'I was diappointed in the flavor and texture of this mix.  I usually like most of the Low Carb things I have tried, but was diappointed in this specific one.',
#   'ProductURL': 'https://www.amazon.com/dp/B000J0HIT2'},
#  {'Unnamed: 0': 31,
#   'Id': 113,
#   'ProductId': 'B0037LW78C',
#   'UserId': 'A2F65U0UDY7TAW',
#   'ProfileName': 'Aldo',
#   'HelpfulnessNumerator': 2,
#   'HelpfulnessDenominator': 2,
#   'Score': 5,
#   'Time': 1337990400,
#   'Summary': 'My every day green tea',
#   'Text': 'I have been drinking Royal King 100% Natural Organic Green Tea (100 tea bags x 2g each) as my every day tea for several years now.  I buy 12 boxes at a time to save on shipping.  For many years I used to drink coffee from morning till night.  But finally I realized that drinking so much coffee was not healthy for me.  I finally resolved to improve my health and stopped drinking coffee all together.  I tried many alternative drinks to replace my coffee habit.  I found that green tea was not only good tasting it also has health benefits.  Green tea is one of the few drinks that actually makes you healthier (coffe and other drinks do not) - the only healthier drink is quality cold water.  In my opinion, for the price, Royal King 100% Natural Organic Green Tea is one of the best tasting teas.  This green tea has a beautiful golden color, the taste is bright and fresh.  I recommend adding a tiny amount of Y.S. Organic Bee Farms RAW HONEY to the tea to add sweetness and health benefits too.  I also give myself a treat once in a while by having a much more expense tea (Tribute Xi Hu Long Jing) but this fantastic tea is not practical for me to drink as my every day tea (although I would if I could afford it).<br /><br />Cons:  On my latest shipment the package shown on the Amazon page is different than the one shipped.  The one shipped displays "NATURALLY HIGH IN POLYPHENOL CATECHINS" (a key contributive element to the possible health effects of tea), whereas the Amazon package displays "CAFFENE FREE".  So I am not sure if this green tea is Caffene free or not.  The other con is that sometimes the tea bag rips open when I unwrap the string from around the tea bag. So if the string seems stuck to the tea bag I put the bag in the hot water to unstick it.',
#   'ProductURL': 'https://www.amazon.com/dp/B0037LW78C'},
#  {'Unnamed: 0': 32,
#   'Id': 117,
#   'ProductId': 'B0026Y3YBK',
#   'UserId': 'A3P60QLFDDCHOY',
#   'ProfileName': 'Giordano "GB"',
#   'HelpfulnessNumerator': 2,
#   'HelpfulnessDenominator': 2,
#   'Score': 5,
#   'Time': 1304899200,
#   'Summary': 'Great cookies',
#   'Text': "I'm Italian and I lived in Italy for years. I used to buy these cookies for my everyday breakfast with an Italian espresso. I couldn't find them anywhere here in the Bay area, so it's great to have them again.",
#   'ProductURL': 'https://www.amazon.com/dp/B0026Y3YBK'},
#  {'Unnamed: 0': 33,
#   'Id': 128,
#   'ProductId': 'B003OB0IB8',
#   'UserId': 'A34UG2TNXIL0Y',
#   'ProfileName': 'Austin H.',
#   'HelpfulnessNumerator': 4,
#   'HelpfulnessDenominator': 4,
#   'Score': 4,
#   'Time': 1325808000,
#   'Summary': 'Tastes great. Love Hot & Spicy. Bad price here.',
#   'Text': "I've been a fan of Hot & Spicy Maruchan Ramen for a long time. If you enjoy spice, and love ramen, you'll love this product. Too bad it's way too expensive here on Amazon. It's only $3.36 per 12 at my Walmart.",
#   'ProductURL': 'https://www.amazon.com/dp/B003OB0IB8'},
#  {'Unnamed: 0': 34,
#   'Id': 130,
#   'ProductId': 'B003OB0IB8',
#   'UserId': 'A28D854VMOEHGX',
#   'ProfileName': 'Benny',
#   'HelpfulnessNumerator': 3,
#   'HelpfulnessDenominator': 3,
#   'Score': 3,
#   'Time': 1329436800,
#   'Summary': 'It burns!',
#   'Text': "I LOVE spicy ramen, but for whatever reasons this thing burns my stomach badly and the burning sensation doesn't go away for like 3 hours! Not sure if that is healthy or not .... and you can buy this at Walmart for $0.28, way cheaper than Amazon.",
#   'ProductURL': 'https://www.amazon.com/dp/B003OB0IB8'},
#  {'Unnamed: 0': 35,
#   'Id': 131,
#   'ProductId': 'B003OB0IB8',
#   'UserId': 'AISIYS3D2EAOX',
#   'ProfileName': 'RTyst',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1330473600,
#   'Summary': 'Amazing to the last bite.',
#   'Text': 'Always being a fan of ramen as a quick and easy meal, finding it on amazon for a decent price and having it delivered to your door by the case is an amazing situation for anyone to find themselves in.',
#   'ProductURL': 'https://www.amazon.com/dp/B003OB0IB8'},
#  {'Unnamed: 0': 36,
#   'Id': 133,
#   'ProductId': 'B003OB0IB8',
#   'UserId': 'A56HS2VNURVJ0',
#   'ProfileName': 'J. Espinoza "jchav1980"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1343606400,
#   'Summary': 'Great spicy flavor',
#   'Text': "I really loved the spicy flavor these had.  I found myself liking the broth more than the noodles which is usually the opposite.  If you aren't used to the heat this might bother you and if you like hot hot foods this might not be enough.",
#   'ProductURL': 'https://www.amazon.com/dp/B003OB0IB8'},
#  {'Unnamed: 0': 37,
#   'Id': 148,
#   'ProductId': 'B0017I8UME',
#   'UserId': 'ATBE88PKKQTRA',
#   'ProfileName': 'Matthew R Lehmkuhler',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1344384000,
#   'Summary': 'Love the salsa!!',
#   'Text': 'This is one of the best salsas that I have found in a long time but stay away from the variety pack. The other two that come with it are not worth your money.',
#   'ProductURL': 'https://www.amazon.com/dp/B0017I8UME'},
#  {'Unnamed: 0': 38,
#   'Id': 156,
#   'ProductId': 'B000SV90J8',
#   'UserId': 'A3OO3TXDSIJDHY',
#   'ProfileName': 'pianolover',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1323648000,
#   'Summary': 'Great flavor of Jell-o.',
#   'Text': "I went to 4 grocery stores looking for this flavor of Jello for my green tomato jam recipe and finally found it here. This jello is wonderful! Evidently it's only carried in the stores during the summer but with harvest time in the Fall, I couldn't find it anywhere in town. This Jello tastes like watermelon and the jam recipe I made with it takes like watermelon jam! Great made as regular Jello too. Yummy!",
#   'ProductURL': 'https://www.amazon.com/dp/B000SV90J8'},
#  {'Unnamed: 0': 39,
#   'Id': 157,
#   'ProductId': 'B0036VM05I',
#   'UserId': 'AUIVXYS8E4DEX',
#   'ProfileName': 'Dr. Christopher Lee',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1327708800,
#   'Summary': 'Great Deal',
#   'Text': 'What a deal this is the healthiest salt you can use.  This box should last our family the year no problem.  Iodized sea salt will not raise your blood pressure as regular salt will.',
#   'ProductURL': 'https://www.amazon.com/dp/B0036VM05I'},
#  {'Unnamed: 0': 40,
#   'Id': 161,
#   'ProductId': 'B000ITVLE2',
#   'UserId': 'ADL44P8Z4A3M5',
#   'ProfileName': 'A. Goldsmith "Media Hound"',
#   'HelpfulnessNumerator': 2,
#   'HelpfulnessDenominator': 2,
#   'Score': 5,
#   'Time': 1323043200,
#   'Summary': 'tasty!',
#   'Text': 'these are the best tasting tuna pack they make in my opinion - make a great on the go snack, and really satisfying with the tomato',
#   'ProductURL': 'https://www.amazon.com/dp/B000ITVLE2'},
#  {'Unnamed: 0': 41,
#   'Id': 165,
#   'ProductId': 'B000ITVLE2',
#   'UserId': 'ARTBQH9WOZTIV',
#   'ProfileName': 'Billy Wilson "amzrview"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 4,
#   'Score': 1,
#   'Time': 1269216000,
#   'Summary': 'Tasteless but low calorie',
#   'Text': 'Seriously this product was as tasteless as they come. There are much better tasting products out there but at 100 calories its better than a special k bar or cookie snack pack. You just have to season it or combine it with something else to share the flavor.',
#   'ProductURL': 'https://www.amazon.com/dp/B000ITVLE2'},
#  {'Unnamed: 0': 42,
#   'Id': 166,
#   'ProductId': 'B003TQQKFQ',
#   'UserId': 'A2TUJ3MOKXZVYK',
#   'ProfileName': 'Amy',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1338508800,
#   'Summary': 'This stuff is sooooo good!',
#   'Text': "I read about pomegranate molasses so I had to try it! I haven't made anything with it yet, just eaten a little bit at a time but WOW is it decadent! It's dark, syrupy, sour, and a little sweet. A dab of this and I forget about dessert. It's just a really unique flavor with a pleasing metallic undertone. Yum!! I'm going to try making fesenjan next :-)",
#   'ProductURL': 'https://www.amazon.com/dp/B003TQQKFQ'},
#  {'Unnamed: 0': 43,
#   'Id': 167,
#   'ProductId': 'B003TQQKFQ',
#   'UserId': 'A2QHQM3HHFUSHG',
#   'ProfileName': 'Catherine Lea',
#   'HelpfulnessNumerator': 2,
#   'HelpfulnessDenominator': 3,
#   'Score': 5,
#   'Time': 1334102400,
#   'Summary': 'Best Stuff Ever',
#   'Text': 'Used this in Moroccan recipes, as a syrup in a brilliant mixed beverage and as a swirled topping on sliced oranges soaked in orange water.  Wonderful, wonderful stuff!',
#   'ProductURL': 'https://www.amazon.com/dp/B003TQQKFQ'},
#  {'Unnamed: 0': 44,
#   'Id': 169,
#   'ProductId': 'B0064KO0BU',
#   'UserId': 'A34D61RQILOKIJ',
#   'ProfileName': 'TampaBayGal',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 1,
#   'Time': 1350086400,
#   'Summary': 'Not Banana Runts',
#   'Text': 'Besides being smaller than runts, they look the same and have the same consistency.  Unfortunately, they taste nothing like banana runts...nor do they even taste good.  Yucky stuff.  Trying to return with vendor.',
#   'ProductURL': 'https://www.amazon.com/dp/B0064KO0BU'},
#  {'Unnamed: 0': 45,
#   'Id': 170,
#   'ProductId': 'B0064KO0BU',
#   'UserId': 'AAV3AEI6YSYA2',
#   'ProfileName': 'sue',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 3,
#   'Time': 1345766400,
#   'Summary': 'Banana Heads Not Banana Runts',
#   'Text': 'The item over all was fine, but the Banana Heads are not just like Banana Runts they are alot smaller. Also when I received the item, the packaging was not great. The Banana Heads had come open during shipping and were all over the packing envelope.',
#   'ProductURL': 'https://www.amazon.com/dp/B0064KO0BU'},
#  {'Unnamed: 0': 46,
#   'Id': 174,
#   'ProductId': 'B0081XN2HQ',
#   'UserId': 'A3HUV0ZQPXO3V7',
#   'ProfileName': 'Pink Dandy Chatter',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1344902400,
#   'Summary': 'Fluffy, Soft, Delicious and Sugary Sweet',
#   'Text': 'I couldn\'t wait to try the 8&#8243; Cinnamon Coffee Cake because it is made with fresh eggs, creamy sour cream, Madagascar Bourbon Vanilla and is topped and filled with cinnamon streusel. This 8&#8243; Cinnamon Coffee Cake is available online for only $18.95. Now, I have had my fair share of cinnamon coffee cakes, but, let me just tell you that the FantasiCakes Cinnamon Coffee Cake really "takes the cake" with size, price, quality and taste.<br />The cake arrived very fast and was carefully packaged so that it arrived in almost perfect condition. It also comes with a large tub of white icing that you can drizzle over the top, before serving. I couldn\'t believe how large the size was and it actually fed my family of 5 for us to enjoy during breakfast, for three days. The cake itself is thick and almost has a solid but sponge cake type consistency that is really moist and very filling. The flavors are to die for with the sticky cinnamon outside and sweet cinnamon and vanilla swirled throughout the inside of the cake. The icing really tops it off beautifully and gives it that moist and sticky sweet flavor. Pair the cake with your morning coffee and you\'ve got the perfect breakfast treat!',
#   'ProductURL': 'https://www.amazon.com/dp/B0081XN2HQ'},
#  {'Unnamed: 0': 47,
#   'Id': 176,
#   'ProductId': 'B0025VRCJY',
#   'UserId': 'A2VYRRDJN2UKWB',
#   'ProfileName': 'Dario Quinonez "aprilkid"',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1299974400,
#   'Summary': 'EXCELLENT LEMON JUICE',
#   'Text': 'One of the best lemon juice that I have tried. I am recurring customer due to the high quality of this product. When the season for fresh lemos is out, this one supplement our need for the citrus on the kitchen or refreshments.<br /><br />I will continue buying it.',
#   'ProductURL': 'https://www.amazon.com/dp/B0025VRCJY'},
#  {'Unnamed: 0': 48,
#   'Id': 182,
#   'ProductId': 'B005CJVVJ8',
#   'UserId': 'A3F44FUPG97AA9',
#   'ProfileName': 'Monie',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1339545600,
#   'Summary': "Marley's Mellow Mood Lite - Half Tea Half Lemonade",
#   'Text': 'This is an great product. The taste is great, and it works exactly as described. Superb natural sleep aid. AMAZING!',
#   'ProductURL': 'https://www.amazon.com/dp/B005CJVVJ8'},
#  {'Unnamed: 0': 49,
#   'Id': 183,
#   'ProductId': 'B005CJVVJ8',
#   'UserId': 'A1AL946PZ24084',
#   'ProfileName': 'Melinda K. Sanders',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 3,
#   'Time': 1334707200,
#   'Summary': 'Great product to help you sleep',
#   'Text': 'WE have been looking for "natural" ways to help us sleep since we always seem to be overloaded with stress and a busy schedule. Yes, we\'d probably be better served taking a yoga class, but this is a good second choice. This helps you fall asleep and stay asleep. I drank half the first night and that was plenty for me. After about 30 minutes, I was ready for bed! I woke up refreshed and with no sleepy-drug hangover, so that is a huge bonus.<br /><br />I gave the product 3 stars (instead of the 5 it deserves) as their packing job was marginal at best. The product arrived with 2 broken bottles, which at this price is a $6 loss! The bottles are glass and all they did was wrap one layer of the small-bubbled bubble wrap around the case and placed it in a larger box with extra room to move around in that box. Big packing fail, but the product is awesome.',
#   'ProductURL': 'https://www.amazon.com/dp/B005CJVVJ8'},
#  {'Unnamed: 0': 50,
#   'Id': 189,
#   'ProductId': 'B004V6AH34',
#   'UserId': 'ATX44LVZL5JFV',
#   'ProfileName': 'Silvy',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 4,
#   'Time': 1314403200,
#   'Summary': 'not bad for instant healthy coffee',
#   'Text': "I bought this coffee because its much cheaper than the ganocafe and has the organic reishi mushroom as well as other healthy antioxidants.  I didn't expect it to taste good, but it actually does!  I've only had it for a few days and for $5 its totally worth it.  My sisters all take ganocafe but now I'm introducing them to this less expensive similar coffee.  I will follow up on this product in a few weeks.  :)",
#   'ProductURL': 'https://www.amazon.com/dp/B004V6AH34'},
#  {'Unnamed: 0': 51,
#   'Id': 191,
#   'ProductId': 'B004V6AH34',
#   'UserId': 'AXAJ1GHE97YE2',
#   'ProfileName': 'Jasmin Song "Jasmin Song"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1339027200,
#   'Summary': 'I love it!',
#   'Text': "This coffee is great because it's all organic ingredients!  No pesticides to worry about, plus it tastes good, and you have the healing effects for ganoderma.",
#   'ProductURL': 'https://www.amazon.com/dp/B004V6AH34'},
#  {'Unnamed: 0': 52,
#   'Id': 193,
#   'ProductId': 'B004V6AH34',
#   'UserId': 'AJZ2A9UOJK0RB',
#   'ProfileName': 'LK',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1336089600,
#   'Summary': 'Tastes Great. Arrived in 2 days!',
#   'Text': 'Tastes great, and gives me energy without the jitters. Love this product.<br />However, I do wish it came in some sort of resealable jar or hard plastic container instead of a zip-lock pouch because the zip-lock ripped off and quit working after awhile. But the product is fantastic, just not crazy about the packaging.',
#   'ProductURL': 'https://www.amazon.com/dp/B004V6AH34'},
#  {'Unnamed: 0': 53,
#   'Id': 194,
#   'ProductId': 'B0028C44Z0',
#   'UserId': 'A19NGYCQ1NCF3W',
#   'ProfileName': 'S. Haney',
#   'HelpfulnessNumerator': 2,
#   'HelpfulnessDenominator': 2,
#   'Score': 5,
#   'Time': 1323820800,
#   'Summary': 'Great for after lunch',
#   'Text': "These little guys are tasty and refreshing.<br /><br />I usually eat salads for lunch which can do terrible things to breath.  I eat 2 of these after lunch (because they are so small) and I find this sufficiently resolves the problem.<br /><br />They're sugar free (sugar can actually help the smelly bacteria grow) which is great and they're tasty enough that I almost think of them as part of my lunch.<br /><br />This is a good bulk value buy and I'd highly recommend the mints themselves.  Cheers!",
#   'ProductURL': 'https://www.amazon.com/dp/B0028C44Z0'},
#  {'Unnamed: 0': 54,
#   'Id': 195,
#   'ProductId': 'B0028C44Z0',
#   'UserId': 'A32DDKLY942A84',
#   'ProfileName': 'PrinterCPE "damnsilly1"',
#   'HelpfulnessNumerator': 2,
#   'HelpfulnessDenominator': 2,
#   'Score': 4,
#   'Time': 1284249600,
#   'Summary': 'Nice little mints, but pricey.',
#   'Text': "I like these better than the regular Altoids, but they're even more costly, so you'd better like them.",
#   'ProductURL': 'https://www.amazon.com/dp/B0028C44Z0'},
#  {'Unnamed: 0': 55,
#   'Id': 198,
#   'ProductId': 'B0028C44Z0',
#   'UserId': 'A4LL4KXLRBQHQ',
#   'ProfileName': 'stillgoinstrong',
#   'HelpfulnessNumerator': 2,
#   'HelpfulnessDenominator': 3,
#   'Score': 3,
#   'Time': 1278460800,
#   'Summary': 'Sugarfree...',
#   'Text': 'Be careful not to eat too many of them in one day, as one of the chemicals in it is the same as that of a LAXATIVE!!! LOLOLOL!!!',
#   'ProductURL': 'https://www.amazon.com/dp/B0028C44Z0'},
#  {'Unnamed: 0': 56,
#   'Id': 201,
#   'ProductId': 'B0028C44Z0',
#   'UserId': 'A1UF2VN3O50NGW',
#   'ProfileName': 'Lou',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 2,
#   'Time': 1330819200,
#   'Summary': 'Altoids Smalls',
#   'Text': "Even with small containers, they don't fill them up.  These little tins are less than half filled and at the price charged it seems a rip-off. Is there some exotic ingredient as costly as gold contained in those tiny squares?  Or how about the cereal ploy, they were filled at the factory but settled in transport.<br />Can manufacturers be honest in their dealings?",
#   'ProductURL': 'https://www.amazon.com/dp/B0028C44Z0'},
#  {'Unnamed: 0': 57,
#   'Id': 203,
#   'ProductId': 'B0028C44Z0',
#   'UserId': 'A3TIC20I6XI297',
#   'ProfileName': 'dog lover',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1320451200,
#   'Summary': 'Altoids',
#   'Text': 'Received as shown. My mother in law likes these and Walgreens quit carrying them. It was great i could get them on Amazon.',
#   'ProductURL': 'https://www.amazon.com/dp/B0028C44Z0'},
#  {'Unnamed: 0': 58,
#   'Id': 212,
#   'ProductId': 'B0009XLVGA',
#   'UserId': 'ATHUN0PJ0MG0P',
#   'ProfileName': 'R. Cross "LVWolfman"',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1315008000,
#   'Summary': 'Great For Fat Cats and Senior Citizens',
#   'Text': 'We have three cats, the youngest is about eleven years old, another is fifteen and our oldest is, well ancient.  That is what the vet told us ten years ago.  The youngest is a blob.  When he lays down, he looks like a footstool. The other two are arthritic and skinny.<br /><br />Since we had such success with Canidae Platinum for senior dogs, I figured that we\'d give it a try for our cats.  I\'d had them on low ash Purina One Urinary tract formula for their entire lives and thankfully we had no UT problems.<br /><br />Buster, the youngest, is still a blob after six months plus on Felidae for Senior and Overweight cats.  However, the other two are now much more active and we can tell that they are really "feeling better" since we changed their food to Felidae.  Even Prissy, the ancient one has started to play and tease the dogs by getting them to chase her, where before when she was on Purina One, all she wanted to do was to sleep.<br /><br />I think that if you can get your cat on this fairly early in their weight problems, it\'ll be more effective.<br /><br />However, the glucosamine will certainly help your older fur balls have a happier life.',
#   'ProductURL': 'https://www.amazon.com/dp/B0009XLVGA'},
#  {'Unnamed: 0': 59,
#   'Id': 214,
#   'ProductId': 'B0009XLVGA',
#   'UserId': 'A1NHQNQ3TVXTZF',
#   'ProfileName': 'Desert Girl "chrissylovesherhusband"',
#   'HelpfulnessNumerator': 3,
#   'HelpfulnessDenominator': 10,
#   'Score': 1,
#   'Time': 1220227200,
#   'Summary': 'CHANGED FORMULA MAKES CATS SICK!!!!',
#   'Text': 'As with canidae, Felidae has also changed their formula.  Cats do not like change when it comes to their food.  And they just had to change it without putting it on their label.  We noticed the color of the food had changed and so did the smell.  (As you will notice I have also reviewd the Canidae, and this all happened the same time the dogs were having issues.)<br /><br />Prior to the change in food we had almost lost two of our cats because we had moved to a new home.  If cats get "upset" because of a change in enviorment, or a loud noise they can stop eating.  It depends on the cat.  Two of them had stopped eating and had lost a lot of weight.  We took them to the vet and it took months to get them back to normal.  It has been a year since then and they are better.  Then the formula for this food changed.<br /><br />We started to noitce they were not eating as much and it started to bug us.  We asked the shop owner of the feed store and she had no knowledge of any change to the food.  It wasn\'t until the we were in there with other customers yelling about their dogs food making their dogs sick.  Right away we changed the cats food and they started chowing down and haven\'t suffered one bit like our dogs have.<br /><br />Cats are sensitve animals and changes to thier food could cause them to stop eating.  Anyone thinking of purchasing this food should not do it!  We have 5 rescued and fixed cats, none of which are picky eaters and the change in this formula could have been the death of them had we not found out about the change in their formula.<br /><br />I urge anyone that has had these problems to go to the consumer affairs website and also the FDA website and write a letter to them to let them know how this has affected your animal.  As with canidae they do not care how the change has affected my animals, and tell me not to buy it.  This is just horrible!',
#   'ProductURL': 'https://www.amazon.com/dp/B0009XLVGA'},
#  {'Unnamed: 0': 60,
#   'Id': 219,
#   'ProductId': 'B001EO5ZMO',
#   'UserId': 'AW497M5SEXAPQ',
#   'ProfileName': 'Neal Pollack',
#   'HelpfulnessNumerator': 5,
#   'HelpfulnessDenominator': 5,
#   'Score': 5,
#   'Time': 1266105600,
#   'Summary': 'Ahmad Loose Imperial Blend Tea is great for the price',
#   'Text': "A friend who'd been drinking tea for 80 of his 84 years introduced me to this tea a few months ago. Even took me over to the store and bought me a pound. At $7/lb. in a retail store or a little over $9 with shipping from an online merchant, I think it's great. I've been drinking Earl Grey, English Breakfast, Irish Breakfast, Lapsang Souchong, Assam, etc. Most of them were over $30/lb. with shipping. Aside from the Lapsang Souchong, I think this is a great replacement for all the rest. Has everything I'm looking for in a strong, full-bodied black tea with enough character to keep it from becoming boring. My current favorite afternoon tea. Unless you're extremely jaded or a tea snob, you'll love it.",
#   'ProductURL': 'https://www.amazon.com/dp/B001EO5ZMO'},
#  {'Unnamed: 0': 61,
#   'Id': 223,
#   'ProductId': 'B001EO5ZMO',
#   'UserId': 'A3JP1UJAF8YY0F',
#   'ProfileName': 'Irish Stu',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1308009600,
#   'Summary': 'My favorite tea',
#   'Text': 'I have tried literally dozens of teas since being introduced to the Russian custom of preparing and drinking tea, and the Ahmad Imperial blend is probably my favorite of all of these due to the fact that it is equally delicious hot or iced.  I buy the three-packs as needed from Amazon and go through them rapidly. My family loves it and my friends have it in their homes now too, try one box of it and you will love it too.',
#   'ProductURL': 'https://www.amazon.com/dp/B001EO5ZMO'},
#  {'Unnamed: 0': 62,
#   'Id': 230,
#   'ProductId': 'B001L4ELRW',
#   'UserId': 'A1AK335P17JXL0',
#   'ProfileName': 'Victoria Brown',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 1,
#   'Time': 1345593600,
#   'Summary': 'Not Good',
#   'Text': "This candy is not as described. The middle is almost hard it is not a silky or smooth filling as described.<br />Looks and tastes like it's way past it's expiration date.<br />Would never reccommend this. Paid a good chunk of cash for nothing",
#   'ProductURL': 'https://www.amazon.com/dp/B001L4ELRW'},
#  {'Unnamed: 0': 63,
#   'Id': 233,
#   'ProductId': 'B003ZFXJDW',
#   'UserId': 'A2HL6876LDPJIM',
#   'ProfileName': 'flageolet',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1343692800,
#   'Summary': 'just give me some watermelon and citron sea salt',
#   'Text': 'i cannot live without this citron falksalt, it is wonderful on watermelon, fish, almost any food requiring salt and in my world it all does.  just try it on red juicy watermelon, wonderful experience.',
#   'ProductURL': 'https://www.amazon.com/dp/B003ZFXJDW'},
#  {'Unnamed: 0': 64,
#   'Id': 241,
#   'ProductId': 'B001EO5ZMY',
#   'UserId': 'AF72GTWZGAC61',
#   'ProfileName': 'Pinkhat',
#   'HelpfulnessNumerator': 3,
#   'HelpfulnessDenominator': 3,
#   'Score': 5,
#   'Time': 1330732800,
#   'Summary': 'Excellent loose tea.',
#   'Text': "If you like the Ceylon tea variety, you will certainly enjoy and appreciate this tea.<br /><br />I am so happy to find Ahmad teas available here (thanks Amazon!) and very surprised at the negative review from 2009 because in the 20+ years we have been drinking Ahmad teas not even once have we been disappointed. The superb quality of Ahmad teas has remained consistent throughout the years.<br /><br />The current deal for the pack of 4 is very good (cheaper than I can find locally).<br /><br />Highly recommended.<br /><br />NOTE: This listing's description is confusing. Each packet of tea weighs 500 grams, which equals 1.1 pounds or 17.6 ounces.",
#   'ProductURL': 'https://www.amazon.com/dp/B001EO5ZMY'},
#  {'Unnamed: 0': 65,
#   'Id': 245,
#   'ProductId': 'B001EO5ZMY',
#   'UserId': 'A1W4LZ4VZDF29Y',
#   'ProfileName': 'Guy S. Painter "gspainter"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 4,
#   'Time': 1275091200,
#   'Summary': 'Ahmad Tea',
#   'Text': 'Ahmad Tea is an excellent looseleaf tea eith hot or for making iced tea. Great flavor with no lingering aftertaste.',
#   'ProductURL': 'https://www.amazon.com/dp/B001EO5ZMY'},
#  {'Unnamed: 0': 66,
#   'Id': 247,
#   'ProductId': 'B007TFONH0',
#   'UserId': 'AMRNVZKWF6519',
#   'ProfileName': 'confettissimo',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1338508800,
#   'Summary': 'Wonderful!',
#   'Text': "I love love love this deal - it's way fun to pick from so many! Teas and chocolates and ciders as well as many coffees. The other outfits that assemble samplers are boring - they do the choosing, and from a much narrower range. The sellers here are very nice, also, and will answer questions via email about the slightly confusing ordering method (it's easy). If you want great packaging, forget it - they ship fast, and the kups are just tossed loose in a box. Who cares?",
#   'ProductURL': 'https://www.amazon.com/dp/B007TFONH0'},
#  {'Unnamed: 0': 67,
#   'Id': 249,
#   'ProductId': 'B007TFONH0',
#   'UserId': 'A3ICO2ROSXHIPM',
#   'ProfileName': 'tightwad',
# ...
#   'Score': 3,
#   'Time': 1258675200,
#   'Summary': 'Not sure',
#   'Text': "I am a energy junkie and I'm not sure if this works or not, but what I do know is that the taste is not the greatest. I do drink the steaz energy drink and I think I get the same results. I like this products because it is  more natural then the others.",
#   'ProductURL': 'https://www.amazon.com/dp/B001UJEN6C'},
#  {'Unnamed: 0': 77,
#   'Id': 294,
#   'ProductId': 'B001UJEN6C',
#   'UserId': 'A2VBZOK3SVSDWA',
#   'ProfileName': 'Jennifer Gray',
#   'HelpfulnessNumerator': 3,
#   'HelpfulnessDenominator': 3,
#   'Score': 5,
#   'Time': 1294790400,
#   'Summary': 'Way better than Guayaki!',
#   'Text': "I had tried both of the Guayaki energy shots and I don't like the taste of either of them! This one has more natural caffeine and tastes much better. I like them cold for sure. My husband and I take these on road trips in a little cooler with ice and waters and we don't have to make stops for coffee! Especially on the turnpikes where it's just way too expensive. It's worth the $[...] per shot. We normally split them. I'm really sensitive to caffeine, even the natural kind so I get a little weird if I drink the whole thing but that's the same for coffee too for me. My husband drinks the whole shot and gets a nice wake up boost. I would recommend these over any of the sinthetic shots out there. You can feel good about putting this in your body! I'll be ordering again soon for sure =)",
#   'ProductURL': 'https://www.amazon.com/dp/B001UJEN6C'},
#  {'Unnamed: 0': 78,
#   'Id': 302,
#   'ProductId': 'B001UJEN6C',
#   'UserId': 'AMYAHFQZI19LS',
#   'ProfileName': 'longlivedave',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1345680000,
#   'Summary': 'Tested by a trucker',
#   'Text': "I drive OTR...Over the Road truck and this helps to keep me alert. It has no sugar high & no crash. I'm on a autoship which i like. The price is very good. I've seen it over 2 bucks in the store.",
#   'ProductURL': 'https://www.amazon.com/dp/B001UJEN6C'},
#  {'Unnamed: 0': 79,
#   'Id': 298,
#   'ProductId': 'B001UJEN6C',
#   'UserId': 'A2Y4IWY1ZXLXH8',
#   'ProfileName': 'mase310',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1335139200,
#   'Summary': 'Favorite energy shot and all natural too!',
#   'Text': "I've tried 5-hour energy, red rain, NOS, and other energy shots.  This is my favorite in terms of taste and effect.  Plus, it's somewhat reassuring to know that natural ingredients are used.  Sometimes I wonder what I'm really putting into my body with some of the other brands.  I purchase a box about once every 2 months for the past 2 years.",
#   'ProductURL': 'https://www.amazon.com/dp/B001UJEN6C'},
#  {'Unnamed: 0': 80,
#   'Id': 312,
#   'ProductId': 'B003YDP5PA',
#   'UserId': 'A18RVAXFLALN6E',
#   'ProfileName': 'DF "Dinky"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 1,
#   'Time': 1343520000,
#   'Summary': 'Very Dissapointed',
#   'Text': 'The package came with the label torn off and no cooking instructions. I know how I normally cook Couscous so tried 3/4 cup water to 1 cup couscous-brought to a boil and let sit, covered for 5min. It was mushy and tasteless.We have thrown out the rest of the container.',
#   'ProductURL': 'https://www.amazon.com/dp/B003YDP5PA'},
#  {'Unnamed: 0': 81,
#   'Id': 314,
#   'ProductId': 'B001EPQ0J0',
#   'UserId': 'A2RXRKRI8YSQWQ',
#   'ProfileName': 'Susan Toy',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1341014400,
#   'Summary': 'Very Good Coffee',
#   'Text': "I love ordering whole bean coffee on Amazon.  I like this so much that this my first product review.  I have to say that I'm usually not a big fan of flavored coffee, but I thought I would give it a try.  When my husband started grinding it up, I could smell it throughout the house.  Sometimes with flavored coffees, the smell is there but the taste isn't.  However, not with this one.  I'm now going to order another flavor from this company and will give it a try.",
#   'ProductURL': 'https://www.amazon.com/dp/B001EPQ0J0'},
#  {'Unnamed: 0': 82,
#   'Id': 318,
#   'ProductId': 'B000O9Y62A',
#   'UserId': 'A89KN0ADLUNPW',
#   'ProfileName': 'Scott E. Packard',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1250208000,
#   'Summary': 'Hot and delicious',
#   'Text': 'I consume about a jar every two weeks of this, either adding it to fajitas or using it as a corn chip dip.  It is hot, but after awhile the medium Salsa Suprema was too mild for me; I thought maybe I\'d cut down how much I ate by going to the hot Salsa Ranchera.  It\'s hot enough that people who aren\'t used to it will say "That\'s hot!".<br /><br />Flavor: bright and forward.  The similarly hot Salsa Victoria is a duller taste to me, I guess earthy.  This salsa is much brighter in the mouth.  I don\'t like to go hotter than this because the sauces I\'ve tried lose any resemblance to yummy salsa and just taste hot (this happens to me with Tabasco sauce, for example).<br /><br />A drawback is La Victoria doesn\'t make a larger bottle of Salsa Ranchera nor Salsa Victoria, nor do they sell them in [...] or Sam\'s Club.  To get a good deal you have to watch for sales.',
#   'ProductURL': 'https://www.amazon.com/dp/B000O9Y62A'},
#  {'Unnamed: 0': 83,
#   'Id': 320,
#   'ProductId': 'B001FB69YY',
#   'UserId': 'AJM8UGFV16NS8',
#   'ProfileName': 'dewalt66',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1316736000,
#   'Summary': 'Oyster Sauce',
#   'Text': 'Use frequently as we like to do Asian dishes at least once a week.  Love this product.  Fast shipping, as usual.  Would buy again.',
#   'ProductURL': 'https://www.amazon.com/dp/B001FB69YY'},
#  {'Unnamed: 0': 84,
#   'Id': 322,
#   'ProductId': 'B000JEHAHS',
#   'UserId': 'AJ7Q49CTJ1BOC',
#   'ProfileName': '24fan',
#   'HelpfulnessNumerator': 4,
#   'HelpfulnessDenominator': 4,
#   'Score': 5,
#   'Time': 1168473600,
#   'Summary': 'Great gag gift',
#   'Text': 'Put this in my husbands stocking for Christmas and it was a hit.',
#   'ProductURL': 'https://www.amazon.com/dp/B000JEHAHS'},
#  {'Unnamed: 0': 85,
#   'Id': 324,
#   'ProductId': 'B000JEHAHS',
#   'UserId': 'A1GUR2DMGWUIGL',
#   'ProfileName': 'Annie "Annie"',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 4,
#   'Score': 3,
#   'Time': 1200182400,
#   'Summary': 'Penguin Pooper',
#   'Text': 'Toy was typical quality I expected.  I got taken for a major ride on the shipping!',
#   'ProductURL': 'https://www.amazon.com/dp/B000JEHAHS'},
#  {'Unnamed: 0': 86,
#   'Id': 329,
#   'ProductId': 'B003VTN95K',
#   'UserId': 'A1J7ZSFU0SO3D4',
#   'ProfileName': 'ck',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1336003200,
#   'Summary': 'Better Packaging',
#   'Text': "Besides the obvious convenience and portability of the individual creamers, I liked this item specifically because of packaging. I couldn't believe how many reviews I read about coffee creamer cups; but many of the Amazon creamer options (both Coffeemate and International Delight) had multiple negative reviews due to the shipment arriving with broken cups thanks to sloppy packaging.<br /><br />That was not an issue here. The shipment arrived in four dispensing boxes of 50 each (as shown in the photo); those boxes were tightly packed in a thick cardboard box which could take a good beating before damaging the inner boxes. Thus, none of my cups were broken, no waste and no sloppy drippy mess. Plus the four boxes means I could put one in the kitchen, one in the bathroom (we moved our mini Keurig there when we upgraded the kitchen Keurig - best idea my husband ever had), and one at work, with a reserve for whichever runs out first.<br /><br />If you are looking for these mini creamers but deterred like I was by the negative packaging reviews on other options, this is your best bet. As a bonus, the auto delivery price is very reasonable.",
#   'ProductURL': 'https://www.amazon.com/dp/B003VTN95K'},
#  {'Unnamed: 0': 87,
#   'Id': 330,
#   'ProductId': 'B003VTN95K',
#   'UserId': 'A3GLQSR6MTHXGL',
#   'ProfileName': 'Donna Kelly',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1330214400,
#   'Summary': 'coffee-mate creamer',
#   'Text': "This seller is very nice.  And the price is very good.  The only reason I stop ording is bacause I went to sugar free, and at that time he did not have it.  But for those of you that don't have to watch there fat in take, I would get this product from them.",
#   'ProductURL': 'https://www.amazon.com/dp/B003VTN95K'},
#  {'Unnamed: 0': 88,
#   'Id': 339,
#   'ProductId': 'B0067LDV66',
#   'UserId': 'A26EQ8U96JA92T',
#   'ProfileName': 'Jody',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1347062400,
#   'Summary': 'Tasty, tasty tasty!',
#   'Text': "I like a lot of sesame oil and use it in salads regularly.  Great quality, flavor and aroma.  Can't beat that its organic!",
#   'ProductURL': 'https://www.amazon.com/dp/B0067LDV66'},
#  {'Unnamed: 0': 89,
#   'Id': 343,
#   'ProductId': 'B000HKYP9A',
#   'UserId': 'A6VEEE9HOL004',
#   'ProfileName': 'Jaime M "Luc\'s Mom"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 3,
#   'Time': 1180224000,
#   'Summary': 'Only good for ice',
#   'Text': "This product is impossible to wash and actually get cleaned.  I couldn't get the food pieces out to save my life. I tried scrubbing them out and even washed it in the dishwasher as it suggests.",
#   'ProductURL': 'https://www.amazon.com/dp/B000HKYP9A'},
#  {'Unnamed: 0': 90,
#   'Id': 348,
#   'ProductId': 'B00067AD4U',
#   'UserId': 'A2OB1BFAEPAYBM',
#   'ProfileName': 'R. C. Wilkins',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1207440000,
#   'Summary': 'Great Beans!!!',
#   'Text': "I ordered these for my coffee themed wedding. When they arrived I had to fight off friends because they smelled and tasted so good. I literally had to hide the box to the wedding! They were a big hit on my wedding day and there were none left over that we put on the tables. It was a great tasting product for the lowest price I've seen!",
#   'ProductURL': 'https://www.amazon.com/dp/B00067AD4U'},
#  {'Unnamed: 0': 91,
#   'Id': 350,
#   'ProductId': 'B00067AD4U',
#   'UserId': 'A2LYOWC3FC73XK',
#   'ProfileName': 'Michael Ekstrum "expresso bean fan"',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1178928000,
#   'Summary': 'excellent - exactly what I expected',
#   'Text': 'The product was exactly as advertised and fresh.  Unfortunately, I keep them in a candy dish in the office and they are going fast.  We need to reorder to keep up with "demand"',
#   'ProductURL': 'https://www.amazon.com/dp/B00067AD4U'},
#  {'Unnamed: 0': 92,
#   'Id': 351,
#   'ProductId': 'B00067AD4U',
#   'UserId': 'A7DSY3M6P6RG3',
#   'ProfileName': 'taza052007',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1181692800,
#   'Summary': 'These are the Best!',
#   'Text': 'These chocolate covered espresso beans are wonderful!  The chocolate is very dark and rich and the "bean" inside is a very delightful blend of flavors with just enough caffine to really give it a zing.',
#   'ProductURL': 'https://www.amazon.com/dp/B00067AD4U'},
#  {'Unnamed: 0': 93,
#   'Id': 353,
#   'ProductId': 'B000SEJ84M',
#   'UserId': 'A19Y7MSOR2J7XP',
#   'ProfileName': 'G. Macleod',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1258588800,
#   'Summary': 'The product is great but the price is out of line',
#   'Text': "I've purchased dozens of bags of this pancake mix (which is a great product, by the way).  This is the highest price I've seen.  Whole Foods carries this item and it's been on sale there for $9.99 (that's Canadian dollars, too, as I'm in Canada).  It's even cheaper on Baker's Box's own website, and they're the company selling this product through Amazon. For a two-pack they should be charging $20 or less.  What gives?  I thought Amazon was where you could find competitive prices.",
#   'ProductURL': 'https://www.amazon.com/dp/B000SEJ84M'},
#  {'Unnamed: 0': 94,
#   'Id': 362,
#   'ProductId': 'B0041QJSJS',
#   'UserId': 'A20B2BU1ZPY9AW',
#   'ProfileName': 'Mr Coffee',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 1,
#   'Score': 1,
#   'Time': 1345507200,
#   'Summary': 'Bitter',
#   'Text': 'A very bitter tasting coffee even when enhanced with cream and/or honey. Definately not my cup of coffee. Oh, did i say it was bitter?',
#   'ProductURL': 'https://www.amazon.com/dp/B0041QJSJS'},
#  {'Unnamed: 0': 95,
#   'Id': 363,
#   'ProductId': 'B0041QJSJS',
#   'UserId': 'A2T68P9I05KBFT',
#   'ProfileName': 'Rusy',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1328054400,
#   'Summary': 'Drinking it now, love the latin america "aroma"',
#   'Text': 'Im learning that Latin American and South American coffees have this distinct "coffee" caramelish finish.  As a Peets Coffee fanatics we learned that Weavers roaster was the roaster for Peet\'s and we are hooked !  I already reviewd the French and Organic blend, but I must say this coffee here is a perfect afternoon drink.<br />Met the weavers team at the Warner Brothers party and they gave me a half a pound of french roast.  Since them we are fans.<br />You wont be dissapointed !',
#   'ProductURL': 'https://www.amazon.com/dp/B0041QJSJS'},
#  {'Unnamed: 0': 96,
#   'Id': 364,
#   'ProductId': 'B00437JI8Q',
#   'UserId': 'A2SLZMD0UYRT5X',
#   'ProfileName': "cat's food",
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1323993600,
#   'Summary': 'GREAT SNACK',
#   'Text': 'I like eating these whenever I need an energy boost.<br />It has everything that I am searching for in a, "To Go Snack".<br />Fiber plus Chocolate is never a bad thing!!!',
#   'ProductURL': 'https://www.amazon.com/dp/B00437JI8Q'},
#  {'Unnamed: 0': 97,
#   'Id': 366,
#   'ProductId': 'B00437JI8Q',
#   'UserId': 'A4TLHOUT1PHTL',
#   'ProfileName': 'Alison',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1346198400,
#   'Summary': "Can't find anywhere else!",
#   'Text': "My fiance loves these dark chocolate and nut granola bars and all the grocery stores around us don't carry them anymore!  Once again, Amazon came through and he couldn't be happier.",
#   'ProductURL': 'https://www.amazon.com/dp/B00437JI8Q'},
#  {'Unnamed: 0': 98,
#   'Id': 370,
#   'ProductId': 'B002O3VHXU',
#   'UserId': 'A3OXHLG6DIBRW8',
#   'ProfileName': 'C. F. Hill "CFH"',
#   'HelpfulnessNumerator': 1,
#   'HelpfulnessDenominator': 1,
#   'Score': 5,
#   'Time': 1282176000,
#   'Summary': 'Very Smooth Coffee - Highly Recommended',
#   'Text': 'Green Mountain "Nantucket Blend" K-Cups make a very good cup of coffee in my <a href="http://www.amazon.com/gp/product/B000AQPMHA">Keurig B-40 B40 Elite Gourmet Single-Cup Home-Brewing System</a>. This is a very smooth tasting brew that my wife prefers over the <a href="http://www.amazon.com/gp/product/B0029XDZIK">Coffee People, Donut Shop K-Cups for Keurig Brewers (Pack of 50) [Amazon Frustration-Free Packaging</a>] I generally drink in the morning.<br /><br />These are good on both "Small" and "Large" cup settings as well.<br /><br />Highly Recommended!<br /><br />CFH',
#   'ProductURL': 'https://www.amazon.com/dp/B002O3VHXU'},
#  {'Unnamed: 0': 99,
#   'Id': 375,
#   'ProductId': 'B0057FTBYO',
#   'UserId': 'A5IWYNX8RHRKL',
#   'ProfileName': 'J. D. Laughead "jdlaughead"',
#   'HelpfulnessNumerator': 0,
#   'HelpfulnessDenominator': 0,
#   'Score': 5,
#   'Time': 1347840000,
#   'Summary': 'Fantastic Chicken Noodle soup',
#   'Text': "This is just Fantastic Chicken Noodle soup, the best I have ever eaten, with large hearty chunks of chicken,and vegetables and nice large noodles. This soup is just so full bodied, and is seasoned just right.  I am so glad Amazon carries this product.  I just can't find it here in Vermont.",
#   'ProductURL': 'https://www.amazon.com/dp/B0057FTBYO'}]

# %%
mydict = { "name": "John", "address": "Highway 37" }

# %%
x = collection.insert_one(mydict)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 x = collection.insert_one(mydict)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
#     678     write_concern.acknowledged,
#     679 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/collection.py:609, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     597     result = conn.command(
#     598         self.__database.name,
#     599         command,
#    (...)
#     604         retryable_write=retryable_write,
#     605     )
#     607     _check_write_command_response(result)
# --> 609 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     611 if not isinstance(doc, RawBSONDocument):
#     612     return doc.get("_id")
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1522, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1502 def _retryable_write(
#    1503     self,
#    1504     retryable: bool,
#    (...)
#    1507     bulk: Optional[_Bulk] = None,
#    1508 ) -> T:
#    1509     """Execute an operation with consecutive retries if possible
#    1510
#    1511     Returns func()'s return value on success. On error retries the same
#    (...)
#    1520       - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521     """
# -> 1522     with self._tmp_session(session) as s:
#    1523         return self._retry_with_session(retryable, func, s, bulk)
#
# File ~/anaconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1840, in MongoClient._tmp_session(self, session, close)
#    1837     yield session
#    1838     return
# -> 1840 s = self._ensure_session(session)
#    1841 if s:
#    1842     try:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1823, in MongoClient._ensure_session(self, session)
#    1818     return session
#    1820 try:
#    1821     # Don't make implicit sessions causally consistent. Applications
#    1822     # should always opt-in.
# -> 1823     return self.__start_session(True, causal_consistency=False)
#    1824 except (ConfigurationError, InvalidOperation):
#    1825     # Sessions not supported.
#    1826     return None
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1766, in MongoClient.__start_session(self, implicit, **kwargs)
#    1763 def __start_session(self, implicit: bool, **kwargs: Any) -> ClientSession:
#    1764     # Raises ConfigurationError if sessions are not supported.
#    1765     if implicit:
# -> 1766         self._topology._check_implicit_session_support()
#    1767         server_session: Union[_EmptyServerSession, _ServerSession] = _EmptyServerSession()
#    1768     else:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/topology.py:573, in Topology._check_implicit_session_support(self)
#     571 def _check_implicit_session_support(self) -> None:
#     572     with self._lock:
# --> 573         self._check_session_support()
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/topology.py:589, in Topology._check_session_support(self)
#     585         self._select_servers_loop(
#     586             any_server_selector, self.get_server_selection_timeout(), None
#     587         )
#     588 elif not self._description.readable_servers:
# --> 589     self._select_servers_loop(
#     590         readable_server_selector, self.get_server_selection_timeout(), None
#     591     )
#     593 session_timeout = self._description.logical_session_timeout_minutes
#     594 if session_timeout is None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/topology.py:259, in Topology._select_servers_loop(self, selector, timeout, address)
#     256 while not server_descriptions:
#     257     # No suitable servers.
#     258     if timeout == 0 or now > end_time:
# --> 259         raise ServerSelectionTimeoutError(
#     260             f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     261         )
#     263     self._ensure_opened()
#     264     self._request_check_all()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 661394ae5c934acd4340cce5, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
dir(db)
# Out:
# ['_BaseObject__codec_options',
#  '_BaseObject__read_concern',
#  '_BaseObject__read_preference',
#  '_BaseObject__write_concern',
#  '_Database__client',
#  '_Database__name',
#  '__annotations__',
#  '__bool__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_command',
#  '_drop_helper',
#  '_get_encrypted_fields',
#  '_is_protocol',
#  '_list_collections',
#  '_read_preference_for',
#  '_retryable_read_command',
#  '_timeout',
#  '_write_concern_for',
#  'aggregate',
#  'client',
#  'codec_options',
#  'command',
#  'create_collection',
#  'cursor_command',
#  'dereference',
#  'drop_collection',
#  'get_collection',
#  'list_collection_names',
#  'list_collections',
#  'name',
#  'next',
#  'read_concern',
#  'read_preference',
#  'validate_collection',
#  'watch',
#  'with_options',
#  'write_concern']

# %%
header = ['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
       'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text',
       'ProductURL']
reader = test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 header = ['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#       2        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text',
#       3        'ProductURL']
# ----> 4 reader = test
#
# NameError: name 'test' is not defined

# %%
for index, row in test.iterrows():
    collection.insert_one(row.to_dict())
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[51], line 2
#       1 for index, row in test.iterrows():
# ----> 2     collection.insert_one(row.to_dict())
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
#     678     write_concern.acknowledged,
#     679 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/collection.py:609, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     597     result = conn.command(
#     598         self.__database.name,
#     599         command,
#    (...)
#     604         retryable_write=retryable_write,
#     605     )
#     607     _check_write_command_response(result)
# --> 609 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     611 if not isinstance(doc, RawBSONDocument):
#     612     return doc.get("_id")
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1523, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1509 """Execute an operation with consecutive retries if possible
#    1510
#    1511 Returns func()'s return value on success. On error retries the same
#    (...)
#    1520   - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521 """
#    1522 with self._tmp_session(session) as s:
# -> 1523     return self._retry_with_session(retryable, func, s, bulk)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1421, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1416 # Ensure that the options supports retry_writes and there is a valid session not in
#    1417 # transaction, otherwise, we will not support retry behavior for this txn.
#    1418 retryable = bool(
#    1419     retryable and self.options.retry_writes and session and not session.in_transaction
#    1420 )
# -> 1421 return self._retry_internal(
#    1422     func=func,
#    1423     session=session,
#    1424     bulk=bulk,
#    1425     retryable=retryable,
#    1426 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:2416, in _ClientConnectionRetryable._write(self)
#    2412 self._server = self._get_server()
#    2413 supports_session = (
#    2414     self._session is not None and self._server.description.retryable_writes_supported
#    2415 )
# -> 2416 with self._client._checkout(self._server, self._session) as conn:
#    2417     max_wire_version = conn.max_wire_version
#    2418     if self._retryable and not supports_session:
#    2419         # A retry is not possible because this server does
#    2420         # not support sessions raise the last error.
#
# File ~/anaconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1252, in MongoClient._checkout(self, server, session)
#    1250     yield session._pinned_connection
#    1251     return
# -> 1252 with server.checkout(handler=err_handler) as conn:
#    1253     # Pin this session to the selected server or connection.
#    1254     if (
#    1255         in_txn
#    1256         and session
#    (...)
#    1261         )
#    1262     ):
#    1263         session._pin(server, conn)
#
# File ~/anaconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/pool.py:1637, in Pool.checkout(self, handler)
#    1634     assert listeners is not None
#    1635     listeners.publish_connection_check_out_started(self.address)
# -> 1637 conn = self._get_conn(handler=handler)
#    1639 if self.enabled_for_cmap:
#    1640     assert listeners is not None
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/pool.py:1756, in Pool._get_conn(self, handler)
#    1754 else:  # We need to create a new connection
#    1755     try:
# -> 1756         conn = self.connect(handler=handler)
#    1757     finally:
#    1758         with self._max_connecting_cond:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/pool.py:1607, in Pool.connect(self, handler)
#    1604     if handler:
#    1605         handler.contribute_socket(conn, completed_handshake=False)
# -> 1607     conn.authenticate()
#    1608 except BaseException:
#    1609     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/pool.py:1078, in Connection.authenticate(self, reauthenticate)
#    1076 creds = self.opts._credentials
#    1077 if creds:
# -> 1078     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#    1079 self.ready = True
#    1080 if self.enabled_for_cmap:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/auth.py:625, in authenticate(credentials, conn, reauthenticate)
#     623     _authenticate_oidc(credentials, conn, reauthenticate)
#     624 else:
# --> 625     auth_func(credentials, conn)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/auth.py:530, in _authenticate_default(credentials, conn)
#     528         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     529     else:
# --> 530         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     531 else:
#     532     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/auth.py:257, in _authenticate_scram(credentials, conn, mechanism)
#     255 else:
#     256     nonce, first_bare, cmd = _authenticate_scram_start(credentials, mechanism)
# --> 257     res = conn.command(source, cmd)
#     259 assert res is not None
#     260 server_first = res["payload"]
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/pool.py:968, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     966     self._raise_if_not_writable(unacknowledged)
#     967 try:
# --> 968     return command(
#     969         self,
#     970         dbname,
#     971         spec,
#     972         self.is_mongos,
#     973         read_preference,
#     974         codec_options,
#     975         session,
#     976         client,
#     977         check,
#     978         allowable_errors,
#     979         self.address,
#     980         listeners,
#     981         self.max_bson_size,
#     982         read_concern,
#     983         parse_write_concern_error=parse_write_concern_error,
#     984         collation=collation,
#     985         compression_ctx=self.compression_context,
#     986         use_op_msg=self.op_msg_enabled,
#     987         unacknowledged=unacknowledged,
#     988         user_fields=user_fields,
#     989         exhaust_allowed=exhaust_allowed,
#     990         write_concern=write_concern,
#     991     )
#     992 except (OperationFailure, NotPrimaryError):
#     993     raise
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/network.py:192, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     190             client._process_response(response_doc, session)
#     191         if check:
# --> 192             helpers._check_command_response(
#     193                 response_doc,
#     194                 conn.max_wire_version,
#     195                 allowable_errors,
#     196                 parse_write_concern_error=parse_write_concern_error,
#     197             )
#     198 except Exception as exc:
#     199     if publish:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/helpers.py:230, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     227 elif code == 43:
#     228     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 230 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : Authentication failed., full error: {'ok': 0, 'errmsg': 'bad auth : Authentication failed.', 'code': 8000, 'codeName': 'AtlasError'}

# %%
for each in test:
    print(each)
    # for field in header:
    #     row[field] = each[field]
    #     print(row)
# Out:
# Id
# ProductId
# UserId
# ProfileName
# HelpfulnessNumerator
# HelpfulnessDenominator
# Score
# Time
# Summary
# Text
# ProductURL

# %%
test.head(1)
# Out:
#    Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 0   4  B000UA0QIQ  A395BORC6FGVXV        Karl                     3
#
#    HelpfulnessDenominator  Score        Time         Summary  \
# 0                       3      2  1307923200  Cough Medicine
#
#                                                 Text  \
# 0  If you are looking for the secret ingredient i...
#
#                              ProductURL
# 0  https://www.amazon.com/dp/B000UA0QIQ

# %%
test.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text',
#        'ProductURL'],
#       dtype='object')

# %%
test = pd.read_csv('amazon_100.csv',index_col=0)
test
# Out:
#      Id   ProductId          UserId                  ProfileName  \
# 0     4  B000UA0QIQ  A395BORC6FGVXV                         Karl
# 1     7  B006K2ZZ7K  A1SP2KVKFXXRU1            David C. Sullivan
# 2     8  B006K2ZZ7K  A3JRGQVEQN31IQ           Pamela G. Williams
# 3    10  B00171APVA  A21BT40VZCCYT4                Carol A. Reed
# 4    14  B001GVISJM  A18ECVX2RJ7HUE              willie "roadie"
# ..  ...         ...             ...                          ...
# 95  363  B0041QJSJS  A2T68P9I05KBFT                         Rusy
# 96  364  B00437JI8Q  A2SLZMD0UYRT5X                   cat's food
# 97  366  B00437JI8Q   A4TLHOUT1PHTL                       Alison
# 98  370  B002O3VHXU  A3OXHLG6DIBRW8             C. F. Hill "CFH"
# 99  375  B0057FTBYO   A5IWYNX8RHRKL  J. D. Laughead "jdlaughead"
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                      3                       3      2  1307923200
# 1                      0                       0      5  1340150400
# 2                      0                       0      5  1336003200
# 3                      0                       0      5  1351209600
# 4                      2                       2      4  1288915200
# ..                   ...                     ...    ...         ...
# 95                     0                       1      5  1328054400
# 96                     1                       1      5  1323993600
# 97                     0                       0      5  1346198400
# 98                     1                       1      5  1282176000
# 99                     0                       0      5  1347840000
#
#                                             Summary  \
# 0                                    Cough Medicine
# 1     Great!  Just as good as the expensive brands!
# 2                            Wonderful, tasty taffy
# 3                                  Healthy Dog Food
# 4                                 fresh and greasy!
# ..                                              ...
# 95  Drinking it now, love the latin america "aroma"
# 96                                      GREAT SNACK
# 97                        Can't find anywhere else!
# 98          Very Smooth Coffee - Highly Recommended
# 99                    Fantastic Chicken Noodle soup
#
#                                                  Text  \
# 0   If you are looking for the secret ingredient i...
# 1   This saltwater taffy had great flavors and was...
# 2   This taffy is so good.  It is very soft and ch...
# 3   This is a very healthy dog food. Good for thei...
# 4   good flavor! these came securely packed... the...
# ..                                                ...
# 95  Im learning that Latin American and South Amer...
# 96  I like eating these whenever I need an energy ...
# 97  My fiance loves these dark chocolate and nut g...
# 98  Green Mountain "Nantucket Blend" K-Cups make a...
# 99  This is just Fantastic Chicken Noodle soup, th...
#
#                               ProductURL
# 0   https://www.amazon.com/dp/B000UA0QIQ
# 1   https://www.amazon.com/dp/B006K2ZZ7K
# 2   https://www.amazon.com/dp/B006K2ZZ7K
# 3   https://www.amazon.com/dp/B00171APVA
# 4   https://www.amazon.com/dp/B001GVISJM
# ..                                   ...
# 95  https://www.amazon.com/dp/B0041QJSJS
# 96  https://www.amazon.com/dp/B00437JI8Q
# 97  https://www.amazon.com/dp/B00437JI8Q
# 98  https://www.amazon.com/dp/B002O3VHXU
# 99  https://www.amazon.com/dp/B0057FTBYO
#
# [100 rows x 11 columns]

# %% [markdown]
# ### 100 Examples

# %%
amazon_df = pd.read_csv('amazon_df.csv',index_col=0)
test_db = amazon_df.head(100)

# %%
test_db.to_csv('amazon_100.csv')
