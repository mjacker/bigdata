# %% [markdown]
# # Satisfy classifier

# %% [markdown]
# ## Data Load

# %%
import pandas as pd

# %%
import numpy as np

# %%
file_in =  "df_processed_sentimentValue.csv"
# file_out = "df_processed_sentimentValue_isSatisfy.csv"

# %%
df = pd.read_csv(file_in)
df.head()
# Out:
#    _id  Id   ProductId          UserId                      ProfileName  \
# 0    0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1    2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 2    3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 3    1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 4    4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  2011-04-27
# 1                     1                       1      4  2008-08-18
# 2                     3                       3      2  2011-06-13
# 3                     0                       0      1  2012-09-07
# 4                     0                       0      5  2012-10-21
#
#                  Summary                                               Text  \
# ...

# %% [markdown]
# ## Process

# %%
## Your group code starts here

# %%
## your group code ends here

# %% [markdown]
# ## Data save

# %%
# ESTA ES UNA CELDA TEMPORAL PARA MOSTRAR COMO SE ESPERA EL RESUULTADO
df['is-satisfy'] = np.random.randint(0, 1, df.shape[0])
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                       _id  \
# 0             0             0           0  660136d21ab34c5dcc314932
# 1             1             1           1  660136d21ab34c5dcc314934
# 2             2             2           2  660136d21ab34c5dcc314935
# 3             3             3           3  660136d21ab34c5dcc314938
# 4             4             4           4  660136d21ab34c5dcc31493d
#
#    Unnamed: 2  Id   ProductId          UserId         ProfileName  \
# 0           3   4  B000UA0QIQ  A395BORC6FGVXV                Karl
# 1           6   7  B006K2ZZ7K  A1SP2KVKFXXRU1   David C. Sullivan
# 2           7   8  B006K2ZZ7K  A3JRGQVEQN31IQ  Pamela G. Williams
# 3           9  10  B00171APVA  A21BT40VZCCYT4       Carol A. Reed
# 4          13  14  B001GVISJM  A18ECVX2RJ7HUE     willie "roadie"
#
#    HelpfulnessNumerator  ...  Score        Time  \
# 0                     3  ...      2  2011-06-13
# 1                     0  ...      5  2012-06-20
# ...

# %%
df.to_csv(file_out)
